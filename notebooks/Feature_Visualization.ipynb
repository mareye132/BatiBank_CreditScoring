# %%
# feature_visualization.ipynb

# In the first cell, import the necessary libraries and my feature engineering script
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('C:/Users/user/Desktop/Github/BatiBank_CreditScoring/scripts')
from feature_engineering import main  # Import the main function from your script

# %%
# Load my dataset
data = pd.read_csv('C:/Users/user/Desktop/Github/BatiBank_CreditScoring/data/data.csv') 
print(data.columns)
# Out:
# Index(['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId',
#        'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId',
#        'ProductCategory', 'ChannelId', 'Amount', 'Value',
#        'TransactionStartTime', 'PricingStrategy', 'FraudResult'],
#       dtype='object')

# %%
# Call the main feature engineering function
data, aggregate_features = main(data)

# Visualization Example
plt.figure(figsize=(10, 6))
sns.histplot(data['Total_Transaction_Amount'], bins=50, kde=True)
plt.title('Total Transaction Amount Distribution')
plt.xlabel('Total Transaction Amount')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# You can add more visualizations as needed, e.g.:
plt.figure(figsize=(10, 6))
sns.boxplot(x=data['FraudResult'], y=data['Average_Transaction_Amount'])
plt.title('Average Transaction Amount by Fraud Result')
plt.xlabel('Fraud Result')
plt.ylabel('Average Transaction Amount')
plt.grid(True)
plt.show()
