# %%
# First, let's import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('C:/Users/user/Desktop/Github/BatiBank_CreditScoring/scripts')

# Then import your module
import CreditScoringEDA as daf

# %%
data = pd.read_csv('C:/Users/user/Desktop/Github/BatiBank_CreditScoring/data/data.csv')

# %%
# 1. Data Overview
print("Overview of the data:")
daf.data_overview(data)
# Out:
# Overview of the data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  object
#  1   BatchId               95662 non-null  object
#  2   AccountId             95662 non-null  object
#  3   SubscriptionId        95662 non-null  object
#  4   CustomerId            95662 non-null  object
#  5   CurrencyCode          95662 non-null  object
#  6   CountryCode           95662 non-null  int64
#  7   ProviderId            95662 non-null  object
#  8   ProductId             95662 non-null  object
#  9   ProductCategory       95662 non-null  object
#  10  ChannelId             95662 non-null  object
#  11  Amount                95662 non-null  float64
#  12  Value                 95662 non-null  int64
#  13  TransactionStartTime  95662 non-null  object
# ...

# %%
# 2. Summary Statistics
print("Summary statistics of numerical columns:")
daf.summary_statistics(data)
# Out:
# Summary statistics of numerical columns:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %%
# 3. Distribution of a Numerical Feature (for example 'Amount')
print("Distribution of the 'Amount' column:") 
daf.plot_numerical_distribution(data, 'Amount')
# Out:
# Distribution of the 'Amount' column:

# %%
# 4. Distribution of a Categorical Feature (for example 'ProductCategory')
print("Distribution of the 'ProductCategory' column:")
daf.plot_categorical_distribution(data, 'ProductCategory')
# Out:
# Distribution of the 'ProductCategory' column:

# %%
# 5. Correlation Matrix
print("Correlation Matrix:")
daf.correlation_matrix(data)
# Out:
# Correlation Matrix:

# %%
# 6. Missing Values
print("Checking for missing values:")
daf.missing_values(data)
# Out:
# Checking for missing values:
# TransactionId           0.0
# BatchId                 0.0
# AccountId               0.0
# SubscriptionId          0.0
# CustomerId              0.0
# CurrencyCode            0.0
# CountryCode             0.0
# ProviderId              0.0
# ProductId               0.0
# ProductCategory         0.0
# ChannelId               0.0
# Amount                  0.0
# Value                   0.0
# TransactionStartTime    0.0
# PricingStrategy         0.0
# FraudResult             0.0
# dtype: float64

# %%
# 7. Outlier Detection (for example 'Amount')
print("Boxplot to detect outliers in the 'Amount' column:")
daf.boxplot_outliers(data, 'Amount')
# Out:
# Boxplot to detect outliers in the 'Amount' column:
